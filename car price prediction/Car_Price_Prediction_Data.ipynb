# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import requests
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome(r'C:\Users\sawan\Desktop\chromedriver.exe')

# %%
cars_url = []

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=2&pinId=110001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=134&pinId=201301'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=5&pinId=122001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=2378&pinId=400001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=2423&pinId=411001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=4709&pinId=560001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=3686&pinId=500001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=5732&pinId=600001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=777&pinId=700001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=1771&pinId=387315'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=1822&pinId=392001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=2987&pinId=462001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=769&pinId=134101'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=6105&pinId=641001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=6&pinId=121001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=132&pinId=201001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=2130&pinId=302001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=692&pinId=144001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=1620&pinId=361001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=6356&pinId=682001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
url = 'https://www.cars24.com/buy-used-car?sort=P&storeCityId=290&pinId=226001'
driver.get(url)
time.sleep(2)

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    
time.sleep(15)

url=driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')     
for i in url:
    cars_url.append(i.get_attribute("href"))

# %%
len(cars_url)
# Out:
# 6665

# %%
cars_url
# Out:
# ['https://www.cars24.com/buy-used-kia-seltos-2020-cars-new-delhi-1005526164/',
#  'https://www.cars24.com/buy-used-maruti-swift-2020-cars-noida-10547199747/',
#  'https://www.cars24.com/buy-used-maruti-swift-2019-cars-new-delhi-10060599733/',
#  'https://www.cars24.com/buy-used-kia-seltos-2020-cars-gurgaon-10158795723/',
#  'https://www.cars24.com/buy-used-mercedes-benz-c-class-2014-cars-new-delhi-1050064264/',
#  'https://www.cars24.com/buy-used-maruti-swift-2020-cars-new-delhi-10002493744/',
#  'https://www.cars24.com/buy-used-hyundai-i10-2013-cars-gurgaon-10141691737/',
#  'https://www.cars24.com/buy-used-renault-kiger-2021-cars-noida-10576492729/',
#  'https://www.cars24.com/buy-used-mg-astor-2022-cars-new-delhi-10170398732/',
#  'https://www.cars24.com/buy-used-honda-city-2014-cars-gurgaon-10184794731/',
#  'https://www.cars24.com/buy-used-jaguar-xf-2013-cars-ghaziabad-1128366066/',
#  'https://www.cars24.com/buy-used-renault-kwid-2021-cars-noida-10088795742/',
# ...

# %%
url_list = [*set(cars_url)]

# %%
len(url_list)
# Out:
# 4482

# %%
url_list
# Out:
# ['https://www.cars24.com/buy-used-nissan-magnite-2021-cars-hyderabad-10483893723/',
#  'https://www.cars24.com/buy-used-mahindra-thar-2021-cars-gurgaon-10059592770/',
#  'https://www.cars24.com/buy-used-jeep-compass-2017-cars-chennai-1133237149/',
#  'https://www.cars24.com/buy-used-hyundai-eon-2014-cars-bengaluru-10294292730/',
#  'https://www.cars24.com/buy-used-maruti-eeco-2019-cars-chennai-11347991773/',
#  'https://www.cars24.com/buy-used-hyundai-creta-2018-cars-faridabad-1053059921/',
#  'https://www.cars24.com/buy-used-maruti-alto-800-2018-cars-ahmedabad-1146336965/',
#  'https://www.cars24.com/buy-used-hyundai-creta-2015-cars-lucknow-1054977140/',
#  'https://www.cars24.com/buy-used-kia-seltos-2019-cars-mumbai-1036724540/',
#  'https://www.cars24.com/buy-used-mahindra-xuv500-2017-cars-bengaluru-1023019246/',
#  'https://www.cars24.com/buy-used-maruti-baleno-2017-cars-pune-10302494771/',
#  'https://www.cars24.com/buy-used-maruti-dzire-2019-cars-bengaluru-10246590747/',
# ...

# %%
driver = webdriver.Chrome(r'C:\Users\sawan\Desktop\chromedriver.exe')

# %%
Price = []
Name = []
History = []
Kilometers_Driven = []
Last_Service = []
Registration = []
Registered_in = []
Owner = []
Fuel_Type = []
Transmission = []
Insurance = []

Airbags = []
Seat_Upholstery = []
Integrated_Music = [] 
Rear_View_Mirrors = [] 
Engine_start_stop =[]
Central_Locking = [] 
Sunroof_Moonroof = [] 
Rear_AC = [] 
Power_Windows =[] 
Headlamps = []

Fuel_type = [] 
Engine_type = [] 
Drivetrain = [] 
Mileage = []
Steering_type = [] 
Transmission_type = [] 
Max_power = [] 
Fuel_tank_capacity = [] 
Seating_capacity = [] 
Alternate_fuel_type = []



for url in url_list: ##loop for every guitar in the list
    driver.get(url)
    time.sleep(2)
    
    try:
        price= driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div/div/div[1]/div[3]/strong')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-') 
        
        
    try:
        name= driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div/div/div[1]/div[2]/h2')
        Name.append(name.text)
    except NoSuchElementException:
        Name.append('-') 
        
        
    try:
        history= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[1]/strong')
        History.append(history.text)
    except NoSuchElementException:
        History.append('-') 
        
        
    try:
        kilometers_Driven= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[3]/strong')
        Kilometers_Driven.append(kilometers_Driven.text)
    except NoSuchElementException:
        Kilometers_Driven.append('-') 
        
        
    try:
        last_Service= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[5]/strong')
        Last_Service.append(last_Service.text)
    except NoSuchElementException:
        Last_Service.append('-') 
        
    try:
        registration= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[7]/strong')
        Registration.append(registration.text)
    except NoSuchElementException:
        Registration.append('-') 
        
    try:
        registered_in= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[9]/strong')
        Registered_in.append(registered_in.text)
    except NoSuchElementException:
        Registered_in.append('-') 
        
        
        
    try:
        owner= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[2]/strong')
        Owner.append(owner.text)
    except NoSuchElementException:
        Owner.append('-') 
        
    try:
        fuel_Type= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[4]/strong')
        Fuel_Type.append(fuel_Type.text)
    except NoSuchElementException:
        Fuel_Type.append('-') 
        
        
    try:
        transmission= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[6]/strong')
        Transmission.append(transmission.text)
    except NoSuchElementException:
        Transmission.append('-') 
        
        
    try:
        insurance= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[8]/strong')
        Insurance.append(insurance.text)
    except NoSuchElementException:
        Insurance.append('-')    
        
        
    Features=driver.find_element(By.XPATH,"//ul[@class='Qqw8W']/li[2]")
    Features.click()
    
    time.sleep(2) 
        
        
    try:
        integrated_Music= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[5]/strong')
        Integrated_Music.append(integrated_Music.text)
    except NoSuchElementException:
        Integrated_Music.append('-') 
        
        
    try:
        rear_View_Mirrors= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[7]/strong')
        Rear_View_Mirrors.append(rear_View_Mirrors.text)
    except NoSuchElementException:
        Rear_View_Mirrors.append('-') 
        
        
    try:
        engine_start_stop= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[9]/strong')
        Engine_start_stop.append(engine_start_stop.text)
    except NoSuchElementException:
        Engine_start_stop.append('-') 
        
        
    try:
        central_Locking= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[2]/strong')
        Central_Locking.append(central_Locking.text)
    except NoSuchElementException:
        Central_Locking.append('-') 
        
        
    try:
        sunroof_Moonroof= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[4]/strong')
        Sunroof_Moonroof.append(sunroof_Moonroof.text)
    except NoSuchElementException:
        Sunroof_Moonroof.append('-') 
        
        
    try:
        rear_AC= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[6]/strong')
        Rear_AC.append(rear_AC.text)
    except NoSuchElementException:
        Rear_AC.append('-') 
        
        
    try:
        power_Windows= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[8]/strong')
        Power_Windows.append(power_Windows.text)
    except NoSuchElementException:
        Power_Windows.append('-') 
        
        
    try:
        headlamps= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[10]/strong')
        Headlamps.append(headlamps.text)
    except NoSuchElementException:
        Headlamps.append('-') 
            
        
    try:
        airbags= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[1]/strong')
        Airbags.append(airbags.text)
    except NoSuchElementException:
        Airbags.append('-') 
        
        
    try:
        seat_Upholstery= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[3]/strong')
        Seat_Upholstery.append(seat_Upholstery.text)
    except NoSuchElementException:
        Seat_Upholstery.append('-') 
        
        
    Specification=driver.find_element(By.XPATH,"//ul[@class='Qqw8W']/li[3]")
    Specification.click()
    
    time.sleep(1)         
     
        
    try:
        fuel_type= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[1]/strong')
        Fuel_type.append(fuel_type.text)
    except NoSuchElementException:
        Fuel_type.append('-') 
        
        
    try:
        engine_type= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[3]/strong')
        Engine_type.append(engine_type.text)
    except NoSuchElementException:
        Engine_type.append('-') 
        
        
    try:
        drivetrain= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[5]/strong')
        Drivetrain.append(drivetrain.text)
    except NoSuchElementException:
        Drivetrain.append('-') 
        
        
    try:
        mileage= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[7]/strong')
        Mileage.append(mileage.text)
    except NoSuchElementException:
        Mileage.append('-') 
        
        
    try:
        steering_type= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[9]/strong')
        Steering_type.append(steering_type.text)
    except NoSuchElementException:
        Steering_type.append('-') 
        
        
    try:
        transmission_type= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[2]/strong')
        Transmission_type.append(transmission_type.text)
    except NoSuchElementException:
        Transmission_type.append('-') 
        
        
    try:
        max_power= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[4]/strong')
        Max_power.append(max_power.text)
    except NoSuchElementException:
        Max_power.append('-') 
        
        
    try:
        fuel_tank_capacity= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[6]/strong')
        Fuel_tank_capacity.append(fuel_tank_capacity.text)
    except NoSuchElementException:
        Fuel_tank_capacity.append('-') 
        
        
    try:
        seating_capacity= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[8]/strong')
        Seating_capacity.append(seating_capacity.text)
    except NoSuchElementException:
        Seating_capacity.append('-') 
        
        
    try:
        alternate_fuel_type= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[10]/strong')
        Alternate_fuel_type.append(alternate_fuel_type.text)
    except NoSuchElementException:
        Alternate_fuel_type.append('-')

# %%
print(len(Price), 
      len(Name),
      len(Kilometers_Driven),
      len(Last_Service),
      len(Registration),
      len(Registered_in),
      len(Fuel_Type),
      len(Transmission),
      len(Insurance),
      len(Airbags),
      len(Seat_Upholstery),
      len(Integrated_Music),
      len(Rear_View_Mirrors),
      len(Engine_start_stop),
      len(Central_Locking),
      len(Sunroof_Moonroof),
      len(Rear_AC),
      len(Power_Windows),
      len(Headlamps),
      len(Fuel_type),
      len(Engine_type),
      len(Drivetrain),
      len(Mileage),
      len(Steering_type),
      len(Transmission_type),
      len(Max_power),
      len(Fuel_tank_capacity),
      len(Seating_capacity),
      len(Alternate_fuel_type),
      len(History),
     )

# %%
df = pd.DataFrame({
    'Price':Price,
    'Name':Name,
    'Kilometers_Driven':Kilometers_Driven,
    'Last_Service':Last_Service,
    'Registration':Registration,
    'Registered_in':Registered_in,
    'Fuel_Type':Fuel_Type,
    'Transmission':Transmission,
    'Insurance':Insurance,
    'Airbags':Airbags,
    'Seat_Upholstery':Seat_Upholstery,
    'Integrated_Music':Integrated_Music,
    'Rear_View_Mirrors':Rear_View_Mirrors,
    'Engine_start_stop':Engine_start_stop,
    'Central_Locking':Central_Locking,
    'Sunroof_Moonroof':Sunroof_Moonroof,
    'Rear_AC':Rear_AC,
    'Power_Windows':Power_Windows,
    'Headlamps':Headlamps,
    'Fuel_type':Fuel_type,
    'Engine_type':Engine_type,
    'Drivetrain':Drivetrain,
    'Mileage':Mileage,
    'Steering_type':Steering_type,
    'Transmission_type':Transmission_type,
    'Max_power':Max_power,
    'Fuel_tank_capacity':Fuel_tank_capacity,
    'Seating_capacity':Seating_capacity,
    'Alternate_fuel_type':Alternate_fuel_type,
    'History':History,
    'Kilometers_Driven':Kilometers_Driven,
    'Last_Service':Last_Service,
    'Registration':Registration,
    'Registered_in':Registered_in,
    'Fuel_Type':Fuel_Type,
    'Transmission':Transmission,
    'Insurance':Insurance
})

# %%
df.to_csv('CarData.csv')

# %%
driver.close()
